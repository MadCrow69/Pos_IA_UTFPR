# %% [markdown]
# # Especialização em Inteligência Artificial
#
# **Aprendizado de Máquina - Aula 2.3: Técnicas de Amostragem**
#
# Código de exemplo desenvolvido pelo docente [Adriano Rivolli](mailto:rivolli@utpfr.edu.br)
#
# *O código apresenta como realizar as diferentes estratégias de amostragem*

# %%
# Imports
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import resample
from sklearn.model_selection import LeaveOneOut

# %%
# Carregando o dataset diabets para servir de exemplo
diabetes = load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %% [markdown]
# ## Estratégias de Amostragem

# %% [markdown]
# #### Holdout
#
# O método disponível na biblioteca Sklearn é `train_test_split`, a documentação está disponível em:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# Para gerar um conjunto de validação o `X_train` e `y_train` podem ser passados novamente para a função `train_test_split`.

# %%
X_train, X_test, y_train, y_test = train_test_split(df, diabetes.target, test_size=0.3, random_state=0, shuffle=True)

print("Dataset", df.shape, diabetes.target.shape)
print("Train dataset", X_train.shape, y_train.shape)
print("Test dataset", X_test.shape, y_test.shape)

X_test
# Out:
# Dataset (442, 10) (442,)
# Train dataset (309, 10) (309,)
# Test dataset (133, 10) (133,)
#           age       sex       bmi        bp        s1        s2        s3  \
# 362  0.019913  0.050680  0.104809  0.070072 -0.035968 -0.026679 -0.024993
# 249 -0.012780 -0.044642  0.060618  0.052858  0.047965  0.029375 -0.017629
# 271  0.038076  0.050680  0.008883  0.042529 -0.042848 -0.021042 -0.039719
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 400 -0.023677 -0.044642  0.045529  0.090729 -0.018080 -0.035447  0.070730
# ..        ...       ...       ...       ...       ...       ...       ...
# 328 -0.038207 -0.044642  0.067085 -0.060756 -0.029088 -0.023234 -0.010266
# 414  0.081666  0.050680  0.006728 -0.004534  0.109883  0.117056 -0.032356
# 421  0.038076  0.050680  0.016428  0.021872  0.039710  0.045032 -0.043401
# 361  0.041708 -0.044642 -0.007284  0.028758 -0.042848 -0.048286  0.052322
# 415 -0.005515 -0.044642  0.008883 -0.050427  0.025950  0.047224 -0.043401
#
#            s4        s5        s6
# 362 -0.002592  0.003709  0.040343
# 249  0.034309  0.070207  0.007207
# 271 -0.002592 -0.018114  0.007207
# 435 -0.002592 -0.038460 -0.038357
# 400 -0.039493 -0.034522 -0.009362
# ..        ...       ...       ...
# 328 -0.002592 -0.001496  0.019633
# 414  0.091875  0.054720  0.007207
# 421  0.071210  0.049770  0.015491
# 361 -0.076395 -0.072133  0.023775
# 415  0.071210  0.014821  0.003064
#
# [133 rows x 10 columns]

# %% [markdown]
# #### Bootstrap
#
# Não há uma função default para a geração desta estratégia, portanto foi desenvolvida uma função para este fim

# %%
def bootstrap(X, y, random_state=0):
  X_train, y_train = resample(X, y, random_state=random_state)
  X_test = df.drop(np.unique(X_train.index))
  y_test = y[X_test.index]
  return (X_train, X_test, y_train, y_test)

X_train, X_test, y_train, y_test = bootstrap(df, diabetes.target)

print("Indices únicos:\n", np.unique(X_train.index), "\n")
print("Total indicies unicos:", len(np.unique(X_train.index)))
print("Dados de treinamento:",  X_train.shape, y_train.shape)
print("Dados de teste:", X_test.shape, y_test.shape)

X_test
# Out:
# Indices únicos:
#  [  0   2   3   4   5   9  11  13  16  19  22  23  24  25  27  28  29  31
#   32  33  35  36  38  39  40  41  42  43  44  47  48  50  51  53  57  58
#   61  62  63  67  69  70  72  73  74  77  79  80  81  82  83  84  86  87
#   88  91  93  94  95  98  99 104 105 106 109 110 111 114 115 116 117 119
#  120 121 123 125 127 128 129 130 131 133 135 136 138 139 141 143 145 146
#  147 148 149 150 151 152 156 158 160 161 163 164 165 166 168 169 172 174
#  176 177 178 180 182 183 184 185 187 189 191 192 193 195 197 198 199 201
#  202 203 204 207 209 211 212 214 215 216 217 218 219 220 221 222 223 226
#  227 228 232 234 237 238 241 242 243 244 248 251 253 254 255 256 257 258
#  259 260 262 265 266 267 269 270 273 274 275 276 277 279 280 281 282 284
#  285 286 287 288 289 290 291 292 294 295 296 297 300 302 304 305 307 308
#  309 311 314 317 320 321 322 323 324 326 327 328 329 331 333 334 335 337
#  338 340 341 345 347 348 349 352 353 356 357 358 359 360 361 363 364 368
#  369 370 371 372 373 374 376 377 378 379 381 382 383 384 387 388 389 393
#  394 396 397 398 404 405 407 410 411 413 414 416 418 419 420 421 423 425
#  426 427 429 430 431 433 434 437 438 439 440]
#
# Total indicies unicos: 281
# Dados de treinamento: (442, 10) (442,)
# Dados de teste: (161, 10) (161,)
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# ..        ...       ...       ...       ...       ...       ...       ...
# 428  0.048974  0.050680  0.088642  0.087287  0.035582  0.021546 -0.024993
# 432  0.009016 -0.044642  0.055229 -0.005670  0.057597  0.044719 -0.002903
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 1   -0.039493 -0.068332 -0.092204
# 6   -0.039493 -0.062917 -0.038357
# 7    0.017703 -0.035816  0.003064
# 8   -0.002592 -0.014960  0.011349
# 10  -0.076395 -0.062917 -0.034215
# ..        ...       ...       ...
# 428  0.034309  0.066051  0.131470
# 432  0.023239  0.055686  0.106617
# 435 -0.002592 -0.038460 -0.038357
# 436 -0.076395 -0.061176 -0.046641
# 441 -0.039493 -0.004222  0.003064
#
# [161 rows x 10 columns]

# %% [markdown]
# #### Cross-validation
#
# A classe disponível na biblioteca Sklearn é `KFold`, a documentação está disponível em:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold
#
# O método `split` retorna uma lista de interação com os indíces de treino e teste. Diferentemente dos exemplos anteriores, neste caso é retornado os indices que devem ser usados para fazer a seleção das instâncias originais.
#
# Para gerar um conjunto de validação os dados de treinamento podem ser passados para a função `train_test_split` ou gerando um novo objeto do tipo `KFold`.

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=35)
for i, (train_index, test_index) in enumerate(kf.split(df, diabetes.target)):
  X_train = df.loc[train_index,]
  y_train = diabetes.target[train_index]
  X_test = df.loc[test_index,]
  y_test = diabetes.target[test_index]

  print("Partição ", i, X_train.shape, y_train.shape, X_test.shape, y_test.shape)
  print()
# Out:
# Partição  0 (353, 10) (353,) (89, 10) (89,)
#
# Partição  1 (353, 10) (353,) (89, 10) (89,)
#
# Partição  2 (354, 10) (354,) (88, 10) (88,)
#
# Partição  3 (354, 10) (354,) (88, 10) (88,)
#
# Partição  4 (354, 10) (354,) (88, 10) (88,)

# %% [markdown]
# Existem outras classes relacionadas que podem ser úteis aos utilizadores:
#
#
# *   K-fold estratificado para classificação: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold
# *   Resultados da avaliação usando CV: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html#sklearn.model_selection.cross_val_score
# *   Predições da avaliação usando CV: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html#sklearn.model_selection.cross_val_predict

# %% [markdown]
# #### Leave-one-out
#
# A classe disponível na biblioteca Sklearn é `LeaveOneOut`, a documentação está disponível em:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.LeaveOneOut.html#sklearn.model_selection.LeaveOneOut
#
# O método `split` funciona semelhante ao exemplo anterior.

# %%
loo = LeaveOneOut()
for i, (train_index, test_index) in enumerate(loo.split(df, diabetes.target)):
  X_train = df.loc[train_index,]
  y_train = diabetes.target[train_index]
  X_test = df.loc[test_index,]
  y_test = diabetes.target[test_index]

  print((i, X_train.shape, y_train.shape, X_test.index))
# Out:
# (0, (441, 10), (441,), Int64Index([0], dtype='int64'))
# (1, (441, 10), (441,), Int64Index([1], dtype='int64'))
# (2, (441, 10), (441,), Int64Index([2], dtype='int64'))
# (3, (441, 10), (441,), Int64Index([3], dtype='int64'))
# (4, (441, 10), (441,), Int64Index([4], dtype='int64'))
# (5, (441, 10), (441,), Int64Index([5], dtype='int64'))
# (6, (441, 10), (441,), Int64Index([6], dtype='int64'))
# (7, (441, 10), (441,), Int64Index([7], dtype='int64'))
# (8, (441, 10), (441,), Int64Index([8], dtype='int64'))
# (9, (441, 10), (441,), Int64Index([9], dtype='int64'))
# (10, (441, 10), (441,), Int64Index([10], dtype='int64'))
# (11, (441, 10), (441,), Int64Index([11], dtype='int64'))
# (12, (441, 10), (441,), Int64Index([12], dtype='int64'))
# (13, (441, 10), (441,), Int64Index([13], dtype='int64'))
# (14, (441, 10), (441,), Int64Index([14], dtype='int64'))
# (15, (441, 10), (441,), Int64Index([15], dtype='int64'))
# (16, (441, 10), (441,), Int64Index([16], dtype='int64'))
# (17, (441, 10), (441,), Int64Index([17], dtype='int64'))
# (18, (441, 10), (441,), Int64Index([18], dtype='int64'))
# (19, (441, 10), (441,), Int64Index([19], dtype='int64'))
# (20, (441, 10), (441,), Int64Index([20], dtype='int64'))
# (21, (441, 10), (441,), Int64Index([21], dtype='int64'))
# (22, (441, 10), (441,), Int64Index([22], dtype='int64'))
# (23, (441, 10), (441,), Int64Index([23], dtype='int64'))
# (24, (441, 10), (441,), Int64Index([24], dtype='int64'))
# (25, (441, 10), (441,), Int64Index([25], dtype='int64'))
# (26, (441, 10), (441,), Int64Index([26], dtype='int64'))
# (27, (441, 10), (441,), Int64Index([27], dtype='int64'))
# (28, (441, 10), (441,), Int64Index([28], dtype='int64'))
# (29, (441, 10), (441,), Int64Index([29], dtype='int64'))
# (30, (441, 10), (441,), Int64Index([30], dtype='int64'))
# (31, (441, 10), (441,), Int64Index([31], dtype='int64'))
# (32, (441, 10), (441,), Int64Index([32], dtype='int64'))
# (33, (441, 10), (441,), Int64Index([33], dtype='int64'))
# (34, (441, 10), (441,), Int64Index([34], dtype='int64'))
# (35, (441, 10), (441,), Int64Index([35], dtype='int64'))
# (36, (441, 10), (441,), Int64Index([36], dtype='int64'))
# (37, (441, 10), (441,), Int64Index([37], dtype='int64'))
# (38, (441, 10), (441,), Int64Index([38], dtype='int64'))
# (39, (441, 10), (441,), Int64Index([39], dtype='int64'))
# (40, (441, 10), (441,), Int64Index([40], dtype='int64'))
# (41, (441, 10), (441,), Int64Index([41], dtype='int64'))
# (42, (441, 10), (441,), Int64Index([42], dtype='int64'))
# (43, (441, 10), (441,), Int64Index([43], dtype='int64'))
# (44, (441, 10), (441,), Int64Index([44], dtype='int64'))
# (45, (441, 10), (441,), Int64Index([45], dtype='int64'))
# (46, (441, 10), (441,), Int64Index([46], dtype='int64'))
# (47, (441, 10), (441,), Int64Index([47], dtype='int64'))
# (48, (441, 10), (441,), Int64Index([48], dtype='int64'))
# (49, (441, 10), (441,), Int64Index([49], dtype='int64'))
# (50, (441, 10), (441,), Int64Index([50], dtype='int64'))
# (51, (441, 10), (441,), Int64Index([51], dtype='int64'))
# (52, (441, 10), (441,), Int64Index([52], dtype='int64'))
# (53, (441, 10), (441,), Int64Index([53], dtype='int64'))
# (54, (441, 10), (441,), Int64Index([54], dtype='int64'))
# (55, (441, 10), (441,), Int64Index([55], dtype='int64'))
# (56, (441, 10), (441,), Int64Index([56], dtype='int64'))
# (57, (441, 10), (441,), Int64Index([57], dtype='int64'))
# (58, (441, 10), (441,), Int64Index([58], dtype='int64'))
# (59, (441, 10), (441,), Int64Index([59], dtype='int64'))
# (60, (441, 10), (441,), Int64Index([60], dtype='int64'))
# (61, (441, 10), (441,), Int64Index([61], dtype='int64'))
# (62, (441, 10), (441,), Int64Index([62], dtype='int64'))
# (63, (441, 10), (441,), Int64Index([63], dtype='int64'))
# (64, (441, 10), (441,), Int64Index([64], dtype='int64'))
# (65, (441, 10), (441,), Int64Index([65], dtype='int64'))
# (66, (441, 10), (441,), Int64Index([66], dtype='int64'))
# (67, (441, 10), (441,), Int64Index([67], dtype='int64'))
# (68, (441, 10), (441,), Int64Index([68], dtype='int64'))
# (69, (441, 10), (441,), Int64Index([69], dtype='int64'))
# (70, (441, 10), (441,), Int64Index([70], dtype='int64'))
# (71, (441, 10), (441,), Int64Index([71], dtype='int64'))
# (72, (441, 10), (441,), Int64Index([72], dtype='int64'))
# (73, (441, 10), (441,), Int64Index([73], dtype='int64'))
# (74, (441, 10), (441,), Int64Index([74], dtype='int64'))
# (75, (441, 10), (441,), Int64Index([75], dtype='int64'))
# (76, (441, 10), (441,), Int64Index([76], dtype='int64'))
# (77, (441, 10), (441,), Int64Index([77], dtype='int64'))
# (78, (441, 10), (441,), Int64Index([78], dtype='int64'))
# (79, (441, 10), (441,), Int64Index([79], dtype='int64'))
# (80, (441, 10), (441,), Int64Index([80], dtype='int64'))
# (81, (441, 10), (441,), Int64Index([81], dtype='int64'))
# (82, (441, 10), (441,), Int64Index([82], dtype='int64'))
# (83, (441, 10), (441,), Int64Index([83], dtype='int64'))
# (84, (441, 10), (441,), Int64Index([84], dtype='int64'))
# (85, (441, 10), (441,), Int64Index([85], dtype='int64'))
# (86, (441, 10), (441,), Int64Index([86], dtype='int64'))
# (87, (441, 10), (441,), Int64Index([87], dtype='int64'))
# (88, (441, 10), (441,), Int64Index([88], dtype='int64'))
# (89, (441, 10), (441,), Int64Index([89], dtype='int64'))
# (90, (441, 10), (441,), Int64Index([90], dtype='int64'))
# (91, (441, 10), (441,), Int64Index([91], dtype='int64'))
# (92, (441, 10), (441,), Int64Index([92], dtype='int64'))
# (93, (441, 10), (441,), Int64Index([93], dtype='int64'))
# (94, (441, 10), (441,), Int64Index([94], dtype='int64'))
# (95, (441, 10), (441,), Int64Index([95], dtype='int64'))
# (96, (441, 10), (441,), Int64Index([96], dtype='int64'))
# (97, (441, 10), (441,), Int64Index([97], dtype='int64'))
# (98, (441, 10), (441,), Int64Index([98], dtype='int64'))
# (99, (441, 10), (441,), Int64Index([99], dtype='int64'))
# (100, (441, 10), (441,), Int64Index([100], dtype='int64'))
# (101, (441, 10), (441,), Int64Index([101], dtype='int64'))
# (102, (441, 10), (441,), Int64Index([102], dtype='int64'))
# (103, (441, 10), (441,), Int64Index([103], dtype='int64'))
# (104, (441, 10), (441,), Int64Index([104], dtype='int64'))
# (105, (441, 10), (441,), Int64Index([105], dtype='int64'))
# (106, (441, 10), (441,), Int64Index([106], dtype='int64'))
# (107, (441, 10), (441,), Int64Index([107], dtype='int64'))
# (108, (441, 10), (441,), Int64Index([108], dtype='int64'))
# (109, (441, 10), (441,), Int64Index([109], dtype='int64'))
# (110, (441, 10), (441,), Int64Index([110], dtype='int64'))
# (111, (441, 10), (441,), Int64Index([111], dtype='int64'))
# (112, (441, 10), (441,), Int64Index([112], dtype='int64'))
# (113, (441, 10), (441,), Int64Index([113], dtype='int64'))
# (114, (441, 10), (441,), Int64Index([114], dtype='int64'))
# (115, (441, 10), (441,), Int64Index([115], dtype='int64'))
# (116, (441, 10), (441,), Int64Index([116], dtype='int64'))
# (117, (441, 10), (441,), Int64Index([117], dtype='int64'))
# (118, (441, 10), (441,), Int64Index([118], dtype='int64'))
# (119, (441, 10), (441,), Int64Index([119], dtype='int64'))
# (120, (441, 10), (441,), Int64Index([120], dtype='int64'))
# (121, (441, 10), (441,), Int64Index([121], dtype='int64'))
# (122, (441, 10), (441,), Int64Index([122], dtype='int64'))
# (123, (441, 10), (441,), Int64Index([123], dtype='int64'))
# (124, (441, 10), (441,), Int64Index([124], dtype='int64'))
# (125, (441, 10), (441,), Int64Index([125], dtype='int64'))
# (126, (441, 10), (441,), Int64Index([126], dtype='int64'))
# (127, (441, 10), (441,), Int64Index([127], dtype='int64'))
# (128, (441, 10), (441,), Int64Index([128], dtype='int64'))
# (129, (441, 10), (441,), Int64Index([129], dtype='int64'))
# (130, (441, 10), (441,), Int64Index([130], dtype='int64'))
# (131, (441, 10), (441,), Int64Index([131], dtype='int64'))
# (132, (441, 10), (441,), Int64Index([132], dtype='int64'))
# (133, (441, 10), (441,), Int64Index([133], dtype='int64'))
# (134, (441, 10), (441,), Int64Index([134], dtype='int64'))
# (135, (441, 10), (441,), Int64Index([135], dtype='int64'))
# (136, (441, 10), (441,), Int64Index([136], dtype='int64'))
# (137, (441, 10), (441,), Int64Index([137], dtype='int64'))
# (138, (441, 10), (441,), Int64Index([138], dtype='int64'))
# (139, (441, 10), (441,), Int64Index([139], dtype='int64'))
# (140, (441, 10), (441,), Int64Index([140], dtype='int64'))
# (141, (441, 10), (441,), Int64Index([141], dtype='int64'))
# (142, (441, 10), (441,), Int64Index([142], dtype='int64'))
# (143, (441, 10), (441,), Int64Index([143], dtype='int64'))
# (144, (441, 10), (441,), Int64Index([144], dtype='int64'))
# (145, (441, 10), (441,), Int64Index([145], dtype='int64'))
# (146, (441, 10), (441,), Int64Index([146], dtype='int64'))
# (147, (441, 10), (441,), Int64Index([147], dtype='int64'))
# (148, (441, 10), (441,), Int64Index([148], dtype='int64'))
# (149, (441, 10), (441,), Int64Index([149], dtype='int64'))
# (150, (441, 10), (441,), Int64Index([150], dtype='int64'))
# (151, (441, 10), (441,), Int64Index([151], dtype='int64'))
# (152, (441, 10), (441,), Int64Index([152], dtype='int64'))
# (153, (441, 10), (441,), Int64Index([153], dtype='int64'))
# (154, (441, 10), (441,), Int64Index([154], dtype='int64'))
# (155, (441, 10), (441,), Int64Index([155], dtype='int64'))
# (156, (441, 10), (441,), Int64Index([156], dtype='int64'))
# (157, (441, 10), (441,), Int64Index([157], dtype='int64'))
# (158, (441, 10), (441,), Int64Index([158], dtype='int64'))
# (159, (441, 10), (441,), Int64Index([159], dtype='int64'))
# (160, (441, 10), (441,), Int64Index([160], dtype='int64'))
# (161, (441, 10), (441,), Int64Index([161], dtype='int64'))
# (162, (441, 10), (441,), Int64Index([162], dtype='int64'))
# (163, (441, 10), (441,), Int64Index([163], dtype='int64'))
# (164, (441, 10), (441,), Int64Index([164], dtype='int64'))
# (165, (441, 10), (441,), Int64Index([165], dtype='int64'))
# (166, (441, 10), (441,), Int64Index([166], dtype='int64'))
# (167, (441, 10), (441,), Int64Index([167], dtype='int64'))
# (168, (441, 10), (441,), Int64Index([168], dtype='int64'))
# (169, (441, 10), (441,), Int64Index([169], dtype='int64'))
# (170, (441, 10), (441,), Int64Index([170], dtype='int64'))
# (171, (441, 10), (441,), Int64Index([171], dtype='int64'))
# (172, (441, 10), (441,), Int64Index([172], dtype='int64'))
# (173, (441, 10), (441,), Int64Index([173], dtype='int64'))
# (174, (441, 10), (441,), Int64Index([174], dtype='int64'))
# (175, (441, 10), (441,), Int64Index([175], dtype='int64'))
# (176, (441, 10), (441,), Int64Index([176], dtype='int64'))
# (177, (441, 10), (441,), Int64Index([177], dtype='int64'))
# (178, (441, 10), (441,), Int64Index([178], dtype='int64'))
# (179, (441, 10), (441,), Int64Index([179], dtype='int64'))
# (180, (441, 10), (441,), Int64Index([180], dtype='int64'))
# (181, (441, 10), (441,), Int64Index([181], dtype='int64'))
# (182, (441, 10), (441,), Int64Index([182], dtype='int64'))
# (183, (441, 10), (441,), Int64Index([183], dtype='int64'))
# (184, (441, 10), (441,), Int64Index([184], dtype='int64'))
# (185, (441, 10), (441,), Int64Index([185], dtype='int64'))
# (186, (441, 10), (441,), Int64Index([186], dtype='int64'))
# (187, (441, 10), (441,), Int64Index([187], dtype='int64'))
# (188, (441, 10), (441,), Int64Index([188], dtype='int64'))
# (189, (441, 10), (441,), Int64Index([189], dtype='int64'))
# (190, (441, 10), (441,), Int64Index([190], dtype='int64'))
# (191, (441, 10), (441,), Int64Index([191], dtype='int64'))
# (192, (441, 10), (441,), Int64Index([192], dtype='int64'))
# (193, (441, 10), (441,), Int64Index([193], dtype='int64'))
# (194, (441, 10), (441,), Int64Index([194], dtype='int64'))
# (195, (441, 10), (441,), Int64Index([195], dtype='int64'))
# (196, (441, 10), (441,), Int64Index([196], dtype='int64'))
# (197, (441, 10), (441,), Int64Index([197], dtype='int64'))
# (198, (441, 10), (441,), Int64Index([198], dtype='int64'))
# (199, (441, 10), (441,), Int64Index([199], dtype='int64'))
# (200, (441, 10), (441,), Int64Index([200], dtype='int64'))
# (201, (441, 10), (441,), Int64Index([201], dtype='int64'))
# (202, (441, 10), (441,), Int64Index([202], dtype='int64'))
# (203, (441, 10), (441,), Int64Index([203], dtype='int64'))
# (204, (441, 10), (441,), Int64Index([204], dtype='int64'))
# (205, (441, 10), (441,), Int64Index([205], dtype='int64'))
# (206, (441, 10), (441,), Int64Index([206], dtype='int64'))
# (207, (441, 10), (441,), Int64Index([207], dtype='int64'))
# (208, (441, 10), (441,), Int64Index([208], dtype='int64'))
# (209, (441, 10), (441,), Int64Index([209], dtype='int64'))
# (210, (441, 10), (441,), Int64Index([210], dtype='int64'))
# (211, (441, 10), (441,), Int64Index([211], dtype='int64'))
# (212, (441, 10), (441,), Int64Index([212], dtype='int64'))
# (213, (441, 10), (441,), Int64Index([213], dtype='int64'))
# (214, (441, 10), (441,), Int64Index([214], dtype='int64'))
# (215, (441, 10), (441,), Int64Index([215], dtype='int64'))
# (216, (441, 10), (441,), Int64Index([216], dtype='int64'))
# (217, (441, 10), (441,), Int64Index([217], dtype='int64'))
# (218, (441, 10), (441,), Int64Index([218], dtype='int64'))
# (219, (441, 10), (441,), Int64Index([219], dtype='int64'))
# (220, (441, 10), (441,), Int64Index([220], dtype='int64'))
# (221, (441, 10), (441,), Int64Index([221], dtype='int64'))
# (222, (441, 10), (441,), Int64Index([222], dtype='int64'))
# (223, (441, 10), (441,), Int64Index([223], dtype='int64'))
# (224, (441, 10), (441,), Int64Index([224], dtype='int64'))
# (225, (441, 10), (441,), Int64Index([225], dtype='int64'))
# (226, (441, 10), (441,), Int64Index([226], dtype='int64'))
# (227, (441, 10), (441,), Int64Index([227], dtype='int64'))
# (228, (441, 10), (441,), Int64Index([228], dtype='int64'))
# (229, (441, 10), (441,), Int64Index([229], dtype='int64'))
# (230, (441, 10), (441,), Int64Index([230], dtype='int64'))
# (231, (441, 10), (441,), Int64Index([231], dtype='int64'))
# (232, (441, 10), (441,), Int64Index([232], dtype='int64'))
# (233, (441, 10), (441,), Int64Index([233], dtype='int64'))
# (234, (441, 10), (441,), Int64Index([234], dtype='int64'))
# (235, (441, 10), (441,), Int64Index([235], dtype='int64'))
# (236, (441, 10), (441,), Int64Index([236], dtype='int64'))
# (237, (441, 10), (441,), Int64Index([237], dtype='int64'))
# (238, (441, 10), (441,), Int64Index([238], dtype='int64'))
# (239, (441, 10), (441,), Int64Index([239], dtype='int64'))
# (240, (441, 10), (441,), Int64Index([240], dtype='int64'))
# (241, (441, 10), (441,), Int64Index([241], dtype='int64'))
# (242, (441, 10), (441,), Int64Index([242], dtype='int64'))
# (243, (441, 10), (441,), Int64Index([243], dtype='int64'))
# (244, (441, 10), (441,), Int64Index([244], dtype='int64'))
# (245, (441, 10), (441,), Int64Index([245], dtype='int64'))
# (246, (441, 10), (441,), Int64Index([246], dtype='int64'))
# (247, (441, 10), (441,), Int64Index([247], dtype='int64'))
# (248, (441, 10), (441,), Int64Index([248], dtype='int64'))
# (249, (441, 10), (441,), Int64Index([249], dtype='int64'))
# (250, (441, 10), (441,), Int64Index([250], dtype='int64'))
# (251, (441, 10), (441,), Int64Index([251], dtype='int64'))
# (252, (441, 10), (441,), Int64Index([252], dtype='int64'))
# (253, (441, 10), (441,), Int64Index([253], dtype='int64'))
# (254, (441, 10), (441,), Int64Index([254], dtype='int64'))
# (255, (441, 10), (441,), Int64Index([255], dtype='int64'))
# (256, (441, 10), (441,), Int64Index([256], dtype='int64'))
# (257, (441, 10), (441,), Int64Index([257], dtype='int64'))
# (258, (441, 10), (441,), Int64Index([258], dtype='int64'))
# (259, (441, 10), (441,), Int64Index([259], dtype='int64'))
# (260, (441, 10), (441,), Int64Index([260], dtype='int64'))
# (261, (441, 10), (441,), Int64Index([261], dtype='int64'))
# (262, (441, 10), (441,), Int64Index([262], dtype='int64'))
# (263, (441, 10), (441,), Int64Index([263], dtype='int64'))
# (264, (441, 10), (441,), Int64Index([264], dtype='int64'))
# (265, (441, 10), (441,), Int64Index([265], dtype='int64'))
# (266, (441, 10), (441,), Int64Index([266], dtype='int64'))
# (267, (441, 10), (441,), Int64Index([267], dtype='int64'))
# (268, (441, 10), (441,), Int64Index([268], dtype='int64'))
# (269, (441, 10), (441,), Int64Index([269], dtype='int64'))
# (270, (441, 10), (441,), Int64Index([270], dtype='int64'))
# (271, (441, 10), (441,), Int64Index([271], dtype='int64'))
# (272, (441, 10), (441,), Int64Index([272], dtype='int64'))
# (273, (441, 10), (441,), Int64Index([273], dtype='int64'))
# (274, (441, 10), (441,), Int64Index([274], dtype='int64'))
# (275, (441, 10), (441,), Int64Index([275], dtype='int64'))
# (276, (441, 10), (441,), Int64Index([276], dtype='int64'))
# (277, (441, 10), (441,), Int64Index([277], dtype='int64'))
# (278, (441, 10), (441,), Int64Index([278], dtype='int64'))
# (279, (441, 10), (441,), Int64Index([279], dtype='int64'))
# (280, (441, 10), (441,), Int64Index([280], dtype='int64'))
# (281, (441, 10), (441,), Int64Index([281], dtype='int64'))
# (282, (441, 10), (441,), Int64Index([282], dtype='int64'))
# (283, (441, 10), (441,), Int64Index([283], dtype='int64'))
# (284, (441, 10), (441,), Int64Index([284], dtype='int64'))
# (285, (441, 10), (441,), Int64Index([285], dtype='int64'))
# (286, (441, 10), (441,), Int64Index([286], dtype='int64'))
# (287, (441, 10), (441,), Int64Index([287], dtype='int64'))
# (288, (441, 10), (441,), Int64Index([288], dtype='int64'))
# (289, (441, 10), (441,), Int64Index([289], dtype='int64'))
# (290, (441, 10), (441,), Int64Index([290], dtype='int64'))
# (291, (441, 10), (441,), Int64Index([291], dtype='int64'))
# (292, (441, 10), (441,), Int64Index([292], dtype='int64'))
# (293, (441, 10), (441,), Int64Index([293], dtype='int64'))
# (294, (441, 10), (441,), Int64Index([294], dtype='int64'))
# (295, (441, 10), (441,), Int64Index([295], dtype='int64'))
# (296, (441, 10), (441,), Int64Index([296], dtype='int64'))
# (297, (441, 10), (441,), Int64Index([297], dtype='int64'))
# (298, (441, 10), (441,), Int64Index([298], dtype='int64'))
# (299, (441, 10), (441,), Int64Index([299], dtype='int64'))
# (300, (441, 10), (441,), Int64Index([300], dtype='int64'))
# (301, (441, 10), (441,), Int64Index([301], dtype='int64'))
# (302, (441, 10), (441,), Int64Index([302], dtype='int64'))
# (303, (441, 10), (441,), Int64Index([303], dtype='int64'))
# (304, (441, 10), (441,), Int64Index([304], dtype='int64'))
# (305, (441, 10), (441,), Int64Index([305], dtype='int64'))
# (306, (441, 10), (441,), Int64Index([306], dtype='int64'))
# (307, (441, 10), (441,), Int64Index([307], dtype='int64'))
# (308, (441, 10), (441,), Int64Index([308], dtype='int64'))
# (309, (441, 10), (441,), Int64Index([309], dtype='int64'))
# (310, (441, 10), (441,), Int64Index([310], dtype='int64'))
# (311, (441, 10), (441,), Int64Index([311], dtype='int64'))
# (312, (441, 10), (441,), Int64Index([312], dtype='int64'))
# (313, (441, 10), (441,), Int64Index([313], dtype='int64'))
# (314, (441, 10), (441,), Int64Index([314], dtype='int64'))
# (315, (441, 10), (441,), Int64Index([315], dtype='int64'))
# (316, (441, 10), (441,), Int64Index([316], dtype='int64'))
# (317, (441, 10), (441,), Int64Index([317], dtype='int64'))
# (318, (441, 10), (441,), Int64Index([318], dtype='int64'))
# (319, (441, 10), (441,), Int64Index([319], dtype='int64'))
# (320, (441, 10), (441,), Int64Index([320], dtype='int64'))
# (321, (441, 10), (441,), Int64Index([321], dtype='int64'))
# (322, (441, 10), (441,), Int64Index([322], dtype='int64'))
# (323, (441, 10), (441,), Int64Index([323], dtype='int64'))
# (324, (441, 10), (441,), Int64Index([324], dtype='int64'))
# (325, (441, 10), (441,), Int64Index([325], dtype='int64'))
# (326, (441, 10), (441,), Int64Index([326], dtype='int64'))
# (327, (441, 10), (441,), Int64Index([327], dtype='int64'))
# (328, (441, 10), (441,), Int64Index([328], dtype='int64'))
# (329, (441, 10), (441,), Int64Index([329], dtype='int64'))
# (330, (441, 10), (441,), Int64Index([330], dtype='int64'))
# (331, (441, 10), (441,), Int64Index([331], dtype='int64'))
# (332, (441, 10), (441,), Int64Index([332], dtype='int64'))
# (333, (441, 10), (441,), Int64Index([333], dtype='int64'))
# (334, (441, 10), (441,), Int64Index([334], dtype='int64'))
# (335, (441, 10), (441,), Int64Index([335], dtype='int64'))
# (336, (441, 10), (441,), Int64Index([336], dtype='int64'))
# (337, (441, 10), (441,), Int64Index([337], dtype='int64'))
# (338, (441, 10), (441,), Int64Index([338], dtype='int64'))
# (339, (441, 10), (441,), Int64Index([339], dtype='int64'))
# (340, (441, 10), (441,), Int64Index([340], dtype='int64'))
# (341, (441, 10), (441,), Int64Index([341], dtype='int64'))
# (342, (441, 10), (441,), Int64Index([342], dtype='int64'))
# (343, (441, 10), (441,), Int64Index([343], dtype='int64'))
# (344, (441, 10), (441,), Int64Index([344], dtype='int64'))
# (345, (441, 10), (441,), Int64Index([345], dtype='int64'))
# (346, (441, 10), (441,), Int64Index([346], dtype='int64'))
# (347, (441, 10), (441,), Int64Index([347], dtype='int64'))
# (348, (441, 10), (441,), Int64Index([348], dtype='int64'))
# (349, (441, 10), (441,), Int64Index([349], dtype='int64'))
# (350, (441, 10), (441,), Int64Index([350], dtype='int64'))
# (351, (441, 10), (441,), Int64Index([351], dtype='int64'))
# (352, (441, 10), (441,), Int64Index([352], dtype='int64'))
# (353, (441, 10), (441,), Int64Index([353], dtype='int64'))
# (354, (441, 10), (441,), Int64Index([354], dtype='int64'))
# (355, (441, 10), (441,), Int64Index([355], dtype='int64'))
# (356, (441, 10), (441,), Int64Index([356], dtype='int64'))
# (357, (441, 10), (441,), Int64Index([357], dtype='int64'))
# (358, (441, 10), (441,), Int64Index([358], dtype='int64'))
# (359, (441, 10), (441,), Int64Index([359], dtype='int64'))
# (360, (441, 10), (441,), Int64Index([360], dtype='int64'))
# (361, (441, 10), (441,), Int64Index([361], dtype='int64'))
# (362, (441, 10), (441,), Int64Index([362], dtype='int64'))
# (363, (441, 10), (441,), Int64Index([363], dtype='int64'))
# (364, (441, 10), (441,), Int64Index([364], dtype='int64'))
# (365, (441, 10), (441,), Int64Index([365], dtype='int64'))
# (366, (441, 10), (441,), Int64Index([366], dtype='int64'))
# (367, (441, 10), (441,), Int64Index([367], dtype='int64'))
# (368, (441, 10), (441,), Int64Index([368], dtype='int64'))
# (369, (441, 10), (441,), Int64Index([369], dtype='int64'))
# (370, (441, 10), (441,), Int64Index([370], dtype='int64'))
# (371, (441, 10), (441,), Int64Index([371], dtype='int64'))
# (372, (441, 10), (441,), Int64Index([372], dtype='int64'))
# (373, (441, 10), (441,), Int64Index([373], dtype='int64'))
# (374, (441, 10), (441,), Int64Index([374], dtype='int64'))
# (375, (441, 10), (441,), Int64Index([375], dtype='int64'))
# (376, (441, 10), (441,), Int64Index([376], dtype='int64'))
# (377, (441, 10), (441,), Int64Index([377], dtype='int64'))
# (378, (441, 10), (441,), Int64Index([378], dtype='int64'))
# (379, (441, 10), (441,), Int64Index([379], dtype='int64'))
# (380, (441, 10), (441,), Int64Index([380], dtype='int64'))
# (381, (441, 10), (441,), Int64Index([381], dtype='int64'))
# (382, (441, 10), (441,), Int64Index([382], dtype='int64'))
# (383, (441, 10), (441,), Int64Index([383], dtype='int64'))
# (384, (441, 10), (441,), Int64Index([384], dtype='int64'))
# (385, (441, 10), (441,), Int64Index([385], dtype='int64'))
# (386, (441, 10), (441,), Int64Index([386], dtype='int64'))
# (387, (441, 10), (441,), Int64Index([387], dtype='int64'))
# (388, (441, 10), (441,), Int64Index([388], dtype='int64'))
# (389, (441, 10), (441,), Int64Index([389], dtype='int64'))
# (390, (441, 10), (441,), Int64Index([390], dtype='int64'))
# (391, (441, 10), (441,), Int64Index([391], dtype='int64'))
# (392, (441, 10), (441,), Int64Index([392], dtype='int64'))
# (393, (441, 10), (441,), Int64Index([393], dtype='int64'))
# (394, (441, 10), (441,), Int64Index([394], dtype='int64'))
# (395, (441, 10), (441,), Int64Index([395], dtype='int64'))
# (396, (441, 10), (441,), Int64Index([396], dtype='int64'))
# (397, (441, 10), (441,), Int64Index([397], dtype='int64'))
# (398, (441, 10), (441,), Int64Index([398], dtype='int64'))
# (399, (441, 10), (441,), Int64Index([399], dtype='int64'))
# (400, (441, 10), (441,), Int64Index([400], dtype='int64'))
# (401, (441, 10), (441,), Int64Index([401], dtype='int64'))
# (402, (441, 10), (441,), Int64Index([402], dtype='int64'))
# (403, (441, 10), (441,), Int64Index([403], dtype='int64'))
# (404, (441, 10), (441,), Int64Index([404], dtype='int64'))
# (405, (441, 10), (441,), Int64Index([405], dtype='int64'))
# (406, (441, 10), (441,), Int64Index([406], dtype='int64'))
# (407, (441, 10), (441,), Int64Index([407], dtype='int64'))
# (408, (441, 10), (441,), Int64Index([408], dtype='int64'))
# (409, (441, 10), (441,), Int64Index([409], dtype='int64'))
# (410, (441, 10), (441,), Int64Index([410], dtype='int64'))
# (411, (441, 10), (441,), Int64Index([411], dtype='int64'))
# (412, (441, 10), (441,), Int64Index([412], dtype='int64'))
# (413, (441, 10), (441,), Int64Index([413], dtype='int64'))
# (414, (441, 10), (441,), Int64Index([414], dtype='int64'))
# (415, (441, 10), (441,), Int64Index([415], dtype='int64'))
# (416, (441, 10), (441,), Int64Index([416], dtype='int64'))
# (417, (441, 10), (441,), Int64Index([417], dtype='int64'))
# (418, (441, 10), (441,), Int64Index([418], dtype='int64'))
# (419, (441, 10), (441,), Int64Index([419], dtype='int64'))
# (420, (441, 10), (441,), Int64Index([420], dtype='int64'))
# (421, (441, 10), (441,), Int64Index([421], dtype='int64'))
# (422, (441, 10), (441,), Int64Index([422], dtype='int64'))
# (423, (441, 10), (441,), Int64Index([423], dtype='int64'))
# (424, (441, 10), (441,), Int64Index([424], dtype='int64'))
# (425, (441, 10), (441,), Int64Index([425], dtype='int64'))
# (426, (441, 10), (441,), Int64Index([426], dtype='int64'))
# (427, (441, 10), (441,), Int64Index([427], dtype='int64'))
# (428, (441, 10), (441,), Int64Index([428], dtype='int64'))
# (429, (441, 10), (441,), Int64Index([429], dtype='int64'))
# (430, (441, 10), (441,), Int64Index([430], dtype='int64'))
# (431, (441, 10), (441,), Int64Index([431], dtype='int64'))
# (432, (441, 10), (441,), Int64Index([432], dtype='int64'))
# (433, (441, 10), (441,), Int64Index([433], dtype='int64'))
# (434, (441, 10), (441,), Int64Index([434], dtype='int64'))
# (435, (441, 10), (441,), Int64Index([435], dtype='int64'))
# (436, (441, 10), (441,), Int64Index([436], dtype='int64'))
# (437, (441, 10), (441,), Int64Index([437], dtype='int64'))
# (438, (441, 10), (441,), Int64Index([438], dtype='int64'))
# (439, (441, 10), (441,), Int64Index([439], dtype='int64'))
# (440, (441, 10), (441,), Int64Index([440], dtype='int64'))
# (441, (441, 10), (441,), Int64Index([441], dtype='int64'))
