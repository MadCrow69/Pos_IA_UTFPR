# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Caminho para o arquivo CSV
data_path = 'D:\\gitT\\Pos_IA_UTFPR\\RedesNeurais\\Datasets\\treinoMLPClassifierBEBIDAS_blc4.csv'

# Carregar os dados
data = pd.read_csv(data_path)

# Dados fornecidos
X = np.array([
    [0.3841, 0.2021, 0.0000, 0.2438], [0.1765, 0.1613, 0.3401, 0.0843], [0.3170, 0.5786, 0.3387, 0.4192],
    # Dados omitidos para brevidade
])
Y = np.array([
    [1, 0, 0], [1, 0, 0], [0, 1, 0],
    # Dados omitidos para brevidade
])

# Divisão dos dados em treino e teste (70% treino, 30% teste)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Configurações da camada oculta
hidden_layer_sizes = [(5,), (10,), (15,)]

# Armazenar métricas de desempenho
metrics = []

for size in hidden_layer_sizes:
    mlp = MLPClassifier(hidden_layer_sizes=size, activation='logistic', learning_rate_init=0.001, max_iter=5000, tol=1e-6, random_state=42)
    mlp.fit(X_train, Y_train)
    Y_pred = mlp.predict(X_test)
    
    # Calcula a acurácia e o MSE
    accuracy = accuracy_score(Y_test, Y_pred)
    mse = mean_squared_error(Y_test, Y_pred)
    
    metrics.append((size, accuracy, mse, mlp.loss_curve_))

# Exibir métricas de desempenho
for size, accuracy, mse, loss_curve in metrics:
    print(f"Hidden Layer Size: {size}, Accuracy: {accuracy}, MSE: {mse}")
    plt.plot(loss_curve, label=f"Size {size}")

plt.title("Loss Curves for different hidden layer sizes")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# c:\Users\Diego O. Antunes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Diego O. Antunes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Hidden Layer Size: (5,), Accuracy: 0.0, MSE: 0.6666666666666666
# Hidden Layer Size: (10,), Accuracy: 0.0, MSE: 0.6666666666666666
# Hidden Layer Size: (15,), Accuracy: 0.0, MSE: 0.6666666666666666
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Caminho para o arquivo CSV
data_path = 'G:\\Meu Drive\\DATASET\\bebidasTestes.csv'

# Carregar os dados com o separador correto
data = pd.read_csv(data_path, sep=';')

# Dividindo os dados em características (X) e rótulos (Y)
# Supondo que as últimas 3 colunas são os rótulos e as demais são as características
X = data.iloc[:, :-3].values
Y = data.iloc[:, -3:].values

# Verificar e tratar valores NaN ou infinitos em X_train e X_test
X_train = np.nan_to_num(X_train)
X_test = np.nan_to_num(X_test)

# Verificar a forma de Y_train e Y_test
print("Forma de Y_train:", Y_train.shape)
print("Forma de Y_test:", Y_test.shape)


# Dividindo os dados em características (X) e rótulos (Y)
# Supondo que as últimas 3 colunas são os rótulos e as demais são as características
X = data.iloc[:, :-3].values
Y = data.iloc[:, -3:].values

# Divisão dos dados em treino e teste (70% treino, 30% teste)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Configurações da camada oculta e inicialização da lista de métricas
hidden_layer_sizes = [(5,), (10,), (15,)]
metrics = []

# Treinamento e avaliação do modelo para diferentes tamanhos de camada oculta
for size in hidden_layer_sizes:
    mlp = MLPClassifier(hidden_layer_sizes=size, activation='logistic', learning_rate_init=0.001, max_iter=5000, tol=1e-6, random_state=42)
    mlp.fit(X_train, Y_train)
    Y_pred = mlp.predict(X_test)

    # Calcula a acurácia e o MSE
    accuracy = accuracy_score(Y_test, Y_pred.round())
    mse = mean_squared_error(Y_test, Y_pred.round())

    metrics.append((size, accuracy, mse, mlp.loss_curve_))

# Exibindo métricas de desempenho e plotando as curvas de perda
for size, accuracy, mse, loss_curve in metrics:
    print(f"Hidden Layer Size: {size}, Accuracy: {accuracy}, MSE: {mse}")
    plt.plot(loss_curve, label=f"Size {size}")

plt.title("Loss Curves for different hidden layer sizes")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Forma de Y_train: (2, 3)
# Forma de Y_test: (1, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 43
#      41 for size in hidden_layer_sizes:
#      42     mlp = MLPClassifier(hidden_layer_sizes=size, activation='logistic', learning_rate_init=0.001, max_iter=5000, tol=1e-6, random_state=42)
# ---> 43     mlp.fit(X_train, Y_train)
#      44     Y_pred = mlp.predict(X_test)
#      46     # Calcula a acurácia e o MSE
#
# File c:\Users\Diego O. Antunes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Caminho para o arquivo CSV
data_path = 'G:\\Meu Drive\\DATASET\\bebidasTestes.csv'

# Carregar os dados com o separador correto
data = pd.read_csv(data_path, sep=';')

# Dividindo os dados em características (X) e rótulos (Y)
# Supondo que as últimas 3 colunas são os rótulos e as demais são as características
X = data.iloc[:, :-3].values
Y = data.iloc[:, -3:].values

# Verificar e tratar valores NaN ou infinitos em X_train e X_test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Normalizar os dados
# ...

# Configurações da camada oculta e inicialização da lista de métricas
hidden_layer_sizes = [(5,), (10,), (15,)]
metrics = []

# Treinamento e avaliação do modelo para diferentes tamanhos de camada oculta
for size in hidden_layer_sizes:
    mlp = MLPClassifier(hidden_layer_sizes=size, activation='logistic', learning_rate_init=0.001, max_iter=5000, tol=1e-6, random_state=42)
    mlp.fit(X_train, Y_train)
    Y_pred = mlp.predict(X_test)

    # Calcula a acurácia
    accuracy = accuracy_score(Y_test, Y_pred.round())

    # Armazenar as métricas
    metrics.append((size, accuracy, mlp.loss_curve_))

# Exibindo métricas de desempenho
for size, accuracy, loss_curve in metrics:
    print(f"Hidden Layer Size: {size}, Accuracy: {accuracy}")

# Plotar as curvas de perda (se disponível)
if hasattr(mlp, "loss_curve_"):
    import matplotlib.pyplot as plt

    plt.title("Loss Curves for different hidden layer sizes")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")

    for size, accuracy, loss_curve in metrics:
        plt.plot(loss_curve, label=f"Size {size}")

    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 30
#      28 for size in hidden_layer_sizes:
#      29     mlp = MLPClassifier(hidden_layer_sizes=size, activation='logistic', learning_rate_init=0.001, max_iter=5000, tol=1e-6, random_state=42)
# ---> 30     mlp.fit(X_train, Y_train)
#      31     Y_pred = mlp.predict(X_test)
#      33     # Calcula a acurácia
#
# File c:\Users\Diego O. Antunes\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# ...
